# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
name="aqib khan"
print(name.upper())
# Out:
# AQIB KHAN

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
fruit=input("tume konsa fruit pasand h:")
print("characters hain:,len(fruit) ")
# Out:
# mango mango
# characters hain:,len(fruit)

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
sentence="python is fun"
new_sentence =sentence.replace("fun","awesome")
print(new_sentence)
# Out:
# python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
text ="hello world"
index=text.find("world")
print("world index",index,"per start hota he ")
# Out:
# world index 6 per start hota he

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
gmail="AQIBKHAN543GMAIL.COM "
print(gmail.lower())
# Out:
# aqibkhan543gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
sentence ='    python programming    '
clean_sentence = sentence.strip()
print(clean_sentence)
# Out:
# python programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
string = 'Welcome to coding'
count = sentence.count('o')
print (count)
# Out:
# 2

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
age= input("apki age kya h ?")
convert_age = int(age)
print("tumhari age:" ,convert_age)
print(type(convert_age))
# Out:
# apki age kya h ? 34
# tumhari age: 34
# <class 'int'>

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
value = input(" apki value kya h?  ")
float_value = float(value)
convert_value = int(float_value)
print("apki value: " ,convert_value)
print(type (convert_value))
# Out:
#  apki value kya h?   15.99
# apki value:  15
# <class 'int'>

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
value1 = ("pehla number likho:")
value2 =  ("dusra number likho:")

num1 = int("10")
num2 = int ("20")

result = num1 + num2
print ("total:" , result)
# Out:
# total: 30

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
num = 100
string_num = str(num)
print (string_num)
print (type(string_num))
# Out:
# 100
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
price = input("apki price kya h?")
float_value = float(value)
convert_value = int(float_value) 
print("apki price: " , convert_value)
print (type(convert_value))
# Out:
# apki price kya h? 99.5
# apki price:  15
# <class 'int'>

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
value1 = "10" 
value2 = "20"

result = int(value1) + int(value2)
print (result)
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
value = '50.5'
num = float(value)
result = num + 10
print (result)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
name = input("apna naam likho :")
city = input("seher ka name likho :")
print ("hello" + name + ", welcome  to" + city)
# Out:
# apna naam likho : aqib
# seher ka name likho : karachi
# helloaqib, welcome  tokarachi

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
num1 = input("pehla number :")
num2 = input("doosra number :")
product = int(num1)* int(num2) 
print("product :" , product)
# Out:
# pehla number : 12
# doosra number : 14
# product : 168

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
color = input("apna favorite color likho:")
print("i also like " + color)
# Out:
# apna favorite color likho: red
# i also like red

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
birth_year = input("apna birth year likho")
current_year = 2026
age = current_year - int(birth_year)
print("tumhari age :" , age)
# Out:
# apna birth year likho 2007
# tumhari age : 19

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
word = input("ek word likhoo : ")
print(word * 5)
# Out:
# ek word likhoo :  hello
# hellohellohellohellohello

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
mobile = input("apna mobile number likhooo")
print("tumne ye number type kia h" , mobile)
print("iska type hai" , type(mobile))
# Out:
# apna mobile number likhooo 03167383899
# tumne ye number type kia h 03167383899
# iska type hai <class 'str'>

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
a = 10
b = 3
remainder = a % b 
print("remainder : " ,remainder)
# Out:
# remainder :  1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
result = 15 > 10 and 15 < 20
print (result)
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
num = input ("ek number likho : ")
check = int(num) > 100 
print ("100 se bada hai:", check)
# Out:
# ek number likho :  45
# 100 se bada hai: False

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
result = 2 ** 5
print ("2 ki power 5 :" , result)
# Out:
# 2 ki power 5 : 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
print (50==100)
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
x = True
y = False
result = x or y
print("true or false = ", result)
# Out:
# true or false =  True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
num = int(input("ek number likho :"))
if num > 0 :
    print("positive hai")
elif num < 0 :
    print("negitive hai")
else:
    print ("zero hai")
# Out:
# ek number likho : 10
# positive hai

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
age = int(input("apni age likho: ")) 
if age >= 18:
    print ("Eligible for vote")
else: 
    print("not eligible for vote")
# Out:
# apni age likho:  18
# Eligible for vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
num = int(input("ek number likho :"))
if num % 2 == 0:
    print("even hai")
else:
    print("odd hai")
# Out:
# ek number likho : 45
# odd hai

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
value1 = int(input("Pehla number :"))
value2 = int(input("Doosra number :"))
if value1 > value2:
   print ("bada num:" , value1 )
elif num2 > num1:
    print ("bada num: " , value2)
else:
     print("dono barabar hain")
# Out:
# Pehla number : 50
# Doosra number : 90
# bada num:  90

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
marks = int(input("student ke marks likho :"))

if marks > 33:
    print("pass")
else:
    print("fail")
# Out:
# student ke marks likho : 45
# pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
text = input("kuch likhoo:") 

if text=="":
    print("string empty h")
else:
    print("string empty nahi h:" , text)
# Out:
# kuch likhoo: text
# string empty nahi h: text

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
password = input("password likho:")

if password == 'python123':
    print("access granted")

else:
    print("wrong password")
# Out:
# password likho: aqibkhan123
# wrong password

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
num = int(input("ek number likho:"))

if num == 0:
    print("number zero hai")
else:
    print("number zero nahi hai")
# Out:
# ek number likho: 34
# number zero nahi hai

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
marks = int(input("marks likho: "))

if marks >= 90:
    print("grade: A")
elif marks >= 80:
    print("grade: b ")
elif marks >= 70:
    print("grade: c")
elif marks >= 60:
    print("grade: d")
else:
    print("grade: f")
# Out:
# marks likho:  56
# grade: f

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
temp = float(input("temprature likho :")) 

if temp > 30:
    print("hot")
elif temp >= 15 : 
    print("warm")
else:
    print("cold")
# Out:
# temprature likho : 34
# hot

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
num = int(input("ek number likho:"))

if num % 3==0 and num % 5==0:
    print("fizz buzz")
elif num % 3==0:
    print ("fizz")
elif num % 5==0:
    print("buzz")
else:
    print(num)
# Out:
# ek number likho: 6
# fizz

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
char = input ("ek character likho :")

if char in 'aeiou':
    print ("vowel hai")
elif char. isalpha():
    print("consonant hai")
else:
    print("alphabet nahi hai")
# Out:
# ek character likho : i
# vowel hai

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
bill= int(input("shoping ka bill likho: "))

if bill > 5000:
    discount = bill * 0.20
    final_bill = bill - discount
    print("20% discount mila :" , discount )
    print ("final bill :" , final_bill)
elif bill >= 2000:
    discount = bill * 0.10 
    final_bill = bill - discount
    print ("10% discount mila :" , discount )
    print ("final bill :" , final_bill)
else:
    print("no discount")
    print("final bill :" , bill)
# Out:
# shoping ka bill likho:  4000
# 10% discount mila : 400.0
# final bill : 3600.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
age = int(input("age likho:"))

if age >= 0 and age <= 12 :
    print("child")
elif age >= 13 and age <= 19:
    print("teenager")
elif age  >= 20 and age <= 59:
    print ("adult")
elif age >= 60 :
    print ("senior citizen")
else:
    print ("ghalat age ")
# Out:
# age likho: 30
# adult

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
year=int(input("saal likho :"))

if (year%4==0 and year% 100!=0) or (year% 400==0):
    print(year,"leap year hai ")
else:
    print(year,"leap year nahi hai")
# Out:
# saal likho : 56
# 56 leap year hai

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
day_num = int(input(" week ka num likho 1-7: "))
if day_num ==1:
    print("Monday")
elif day_num == 2:
   print("tuesday")
elif day_num == 3:
    print("wednesday")
elif day_num == 4:
    print("thursday")
elif day_num == 5:
    print("friday")
elif day_num == 6:
    print("saturday")
elif day_num == 7:
    print("sunday")
else:
    print("ghalat numbr. 1 se 7 tak likhoo")
# Out:
#  week ka num likho 1-7:  5
# friday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
num1 = float(input("pehla number")) 
num2 = float(input("doosra number"))
operator = input("operator likho + , - , * , / :" )

if operator == '+':
    result = num1 + num2
    print("answer :" , result)
elif operator == '-':
    result = num1 - num2
    print("answer :" , result)
elif operator == '*':
    result = num1 * num2
    print("answer :" , result)
elif operator == '/':
    if num2 !=0:
        result = num1 /  num2
        print("answer :" , result)
    else:
        print("error: zero se divide nhi hota")
else:
    print("ghalat operator")
# Out:
# pehla number 5
# doosra number 6
# operator likho + , - , * , / : -
# answer : -1.0

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
weight = float(input("weight kg me likho:")) 
height = float(input("height meters me likho:"))

bmi = weight / (height * height)
print ("tumhara bmi hai :" , round(bmi , 2))

if bmi < 18.5:
    print("category : underweight")
elif bmi >= 18.5 and bmi <= 24.9:
    print("category : normal")
elif bmi >= 25 and bmi <= 29.9:
    print ("category : overweight")
else:
    print("caregory : obese")
# Out:
# weight kg me likho: 45
# height meters me likho: 5
# tumhara bmi hai : 1.8
# category : underweight

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
correct_pin = 1234
account_balance = 5000

pin = int(input("pin dalo :"))
                
if pin == correct_pin:
    amount = int(input("kitne payse nikalne hen:"))
    
    if amount <= account_balance:
         account_balance = account_balance - amount
         print("withdrawal success")
         print("bacha hua balance:" , account_balance)
    else:
         print ("insuficent balance")
          
else:
    print("ghalat pin")
# Out:
# pin dalo : 7890
# ghalat pin

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
correct_username = "admin"
correct_pasword = "pass123" 

username = input("username likho:")

if username == correct_username:
    password = input("password likho:")
    if password == correct_pasword:
        print("login successful")
    else:
        print("ghalat pasword")
else:
    print("username nahi mila")
# Out:
# username likho: ali
# username nahi mila

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
a = int(input("pehla number :"))
b = int(input("doosra number :"))
c = int(input("teesra number :"))

if a >= b:
    if a >= c:
        print("sabse bada:" , a)
    else:
        print("sabse bada:" , c)
else:
    if b >= c:
        print("sabse bada:" , b)
    else:
        print("sabse bada:" , c)
# Out:
# pehla number : 15
# doosra number : 56
# teesra number : 67
# sabse bada: 67

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
age = int(input("apni age likho :"))

if age >= 18:
    has_id = input("do you have id ? yes/no:").lower()
    if has_id == "yes":
        print ("ticked issued")
    else:
        print("id nahi hai to ticket nahi milega: ")
else:
    print("18 se kam age. ticket nahi milega:")
# Out:
# apni age likho : 16
# 18 se kam age. ticket nahi milega:

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
marks = int(input("student ka marks likho: "))

if marks >= 80:
    interview = input("interview clear hai? yes/no:") 
    
    if interview == "yes":
        print("admission done")
    else:
        print ("interview clear nahi. admishion nahi milega:")
else:
    print("marks 80 se kam hain. admishion nahi milega")
# Out:
# student ka marks likho:  78
# marks 80 se kam hain. admishion nahi milega

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
num = int(input("number likho:"))

if num > 0 :
    print("positive number hai")
    if num > 100:
        print("100 se bada hai")
    else:
        print("100 se chota ya barabar hai")
elif num == 0:
    print("number zero hai")
else:
    print("negative number hai")
# Out:
# number likho: 70
# positive number hai
# 100 se chota ya barabar hai

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
choice = input("veg ya non_veg?").lower()

if choice == "veg":
    dish = input("paneer ya dal?")
    if dish == "paneer":
        print("apka order : paneer")
    elif dish == "dal":
        print("apka order : dal")
    else: 
        print("ghalat option")
elif choice == "non_veg":
    dish = input ("chiken ya mutton?")
    if dish == "chiken":
        print("apka order : chiken")
    elif dish == "mutton":
        print("apka order : mutton")
    else: 
         print("ghalat option")
else:
    print("sirf veg ya non veg likho")
# Out:
# veg ya non_veg? chiken
# sirf veg ya non veg likho

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
num = int(input("number likho"))
abs_num = abs(num)

if abs_num < 10:
    print ("single digit")
elif abs_num < 100:
    print("double digit ")
elif abs_num < 1000:
    print("triple digit")
else:
    print("1000 ya us se bada hai")
# Out:
# number likho 700
# triple digit

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
salary = float(input("salary likho:"))
years = int(input("service year likho:"))

if years > 5:
    bonus = salary * 0.05
    final_salary = salary + bonus
    print("5% bonus mila:" , bonus)
    print("final salary:" , final_salary)
else:
    print("bonus nahi milega")
    print("final salary:" , salary)
# Out:
# salary likho: 50000
# service year likho: 58
# 5% bonus mila: 2500.0
# final salary: 52500.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
a = float(input("pehli side: "))
b = float(input("doosri side: "))
c = float(input("tesri side: "))

if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("equilateral triangle")
    elif a == b or b == c or a == c:
        print("isoceles triangle")
    else:
        print("scalane triangle")
else:
    print ("ye triangle nahi ban sakta")
# Out:
# pehli side:  5
# doosri side:  5
# tesri side:  5
# equilateral triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
month = input ("months ka name likho:") .lower() 
if month == "january" or month == "march" or month == "may" or month == "july" or month == "august" or month == "octuber" or month == "december": 
    print("31 days")
elif month == "april" or month == "june" or month == "september" or month == "november":
    print("30 days")
elif month == "febuary":
    print("28 ya 29 days")
else:
    print("ghalat month ka number")
# Out:
# months ka name likho: january
# 31 days

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
num = int(input("number likho:"))

if num % 2 == 0:
    print ("even number hai")
    if num > 50:
        print("50 se bada hai")
    elif num < 50:
        print("50 se chota hai")
    else: 
        print("50 ke barabar hai")
else:
   print("odd number hai")
# Out:
# number likho: 67
# odd number hai

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
maths = int(input("maths ke marks:"))
science = int(input("science ke marks:"))

if maths >= 40 and science >= 40:
    print ("pass")
else: 
    print("fail")
    if maths < 40:
        print("maths me weak hai")
        if science < 40:
            print("science me weak ha")
# Out:
# maths ke marks: 67
# science ke marks: 56
# pass

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
units = int(input("total units likho"))

if units <= 100:
    bill = 0
    print("bill : 0 rs - pehle 100 units free:")
elif units <= 200:
    bill = (units - 100) * 5
    print ("bill :" , bill, "rs")
else:
    bill = (100*5) + (units - 200 ) * 10
    print ("bill:" , bill , "rs")
# Out:
# total units likho 230
# bill: 800 rs

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
score = int(input("score likho:"))

if score >= 0 and score <= 50:
    print("level : beginner")
elif score >= 51 and score <= 100:
    print("level : intermedate")
    boss = input("boss level kiya? yes/no:").lower
    if boss == "yes":
        print("congrats! boss level clear")
    else: 
        print("boss level karna baaki hai")
else:
    print("score 0-100 ke beach hona cahiye")
# Out:
# score likho: 77
# level : intermedate
# boss level kiya? yes/no: no
# boss level karna baaki hai

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
correct_username = "admin"
correct_password = "python123"
security_ans = "karachi"

print("=== secure login system ===")

username = input("username:")

if username == correct_username:
    print("username sahi hai")

    attempts = 3
    while attempts > 0:
        password = input("password")

        if password == correct_password:
            print("password sahi hai ")

            if password == correct_password:
                print("password sahi hai")
                answer = input("security question:apka city konsa hai?").lower()

                if password == correct_password:
                    print("password sahi hai")
                    answer = input("security question: apka city konsa hai?").lower()

                    if answer == security_ans:
                        print ("login successful")
                        print("welcome" , username)
                        break
                    else:
                        print("ghalat security answer")
                        break
                else:
                    attempts = attempts - 1
                    if attempts > 0:
                        print("3 ghalat password. attempts baaki hain")
                    else:
                        print("3 galat attempts. account locked")
else:
    print("username ghalat hai")
# Out:
# === secure login system ===
